# %%
import pandas as pd
from pathlib import Path
import datetime as dt
import numpy as np

# %%
#Import Raw Median Income by County data
fl_raw_18_df = pd.read_csv(Path("../../../../data/raw_data/ACSST5Y2018.S1903-2024-09-04T005331.csv"))
fl_raw_19_df = pd.read_csv(Path("../../../../data/raw_data/ACSST5Y2019.S1903-2024-09-04T005419.csv"))
fl_raw_20_df = pd.read_csv(Path("../../../../data/raw_data/ACSST5Y2020.S1903-2024-09-04T005442.csv"))
fl_raw_21_df = pd.read_csv(Path("../../../../data/raw_data/ACSST5Y2021.S1903-2024-09-04T005457.csv"))

# %% [markdown]
# 2018 Data

# %%
#2018 Data
print("Shape:",fl_raw_18_df.shape)
display(fl_raw_18_df.columns)
display(fl_raw_18_df.head(10))
# Out:
# Shape: (469, 2)
# Index(['Label (Grouping)', 'HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households'], dtype='object')
#               Label (Grouping)  \
# 0      Alachua County, Florida
# 1                       Number
# 2                     Estimate
# 3         Percent Distribution
# 4                     Estimate
# 5      Median income (dollars)
# 6                     Estimate
# 7        Baker County, Florida
# 8                       Number
# 9                     Estimate
#
#   HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households
# 0                                                NaN
# 1                                                NaN
# 2                                             97,048
# 3                                                NaN
# 4                                             97,048
# 5                                                NaN
# 6                                             49,078
# ...

# %%
#Rename 2018 Columns
fl_18_df = fl_raw_18_df.rename(columns={"Label (Grouping)":"County","HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households":"2018 Median Income"})
fl_18_df.head(20)
# Out:
#                          County 2018 Median Income
# 0       Alachua County, Florida                NaN
# 1                        Number                NaN
# 2                      Estimate             97,048
# 3          Percent Distribution                NaN
# 4                      Estimate             97,048
# 5       Median income (dollars)                NaN
# 6                      Estimate             49,078
# 7         Baker County, Florida                NaN
# 8                        Number                NaN
# 9                      Estimate              8,625
# 10         Percent Distribution                NaN
# 11                     Estimate              8,625
# 12      Median income (dollars)                NaN
# 13                     Estimate             61,769
# 14          Bay County, Florida                NaN
# 15                       Number                NaN
# 16                     Estimate             70,199
# ...

# %%
keep_columns = 'County'

unpivot_columns = None

df = fl_18_df.melt(
    id_vars=None,
    value_vars=None,
    var_name=None,
    value_name=None,
    # col_level=None
)

# %%
#Delete 2010 Extra Rows
rows_delete_10 = [1:4,8:11,15:18,22:25,29:32,36:39,43:46,50:53,57:60,64:67,71:74,78:81
