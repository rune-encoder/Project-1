# %%
import pandas as pd
from pathlib import Path
import datetime as dt
import numpy as np
import hvplot.pandas
import matplotlib.pyplot as plt

# %%
#Import main Florida dataset
fl_ev_df = pd.read_csv(Path("../../../../data/processed_data/fl_ev_main_dataset.csv"))

# %%
#Examine Data
print("Shape:",fl_ev_df.shape)
display(fl_ev_df.columns)
display(fl_ev_df.head(10))
# Out:
# Shape: (268, 7)
# Index(['year', 'state', 'county', 'zip_codes', 'population',
#        'ev_registrations', 'median_income'],
#       dtype='object')
#    year state            county  \
# 0  2018    FL    Alachua County
# 1  2018    FL      Baker County
# 2  2018    FL        Bay County
# 3  2018    FL   Bradford County
# 4  2018    FL    Brevard County
# 5  2018    FL    Broward County
# 6  2018    FL    Calhoun County
# 7  2018    FL  Charlotte County
# 8  2018    FL     Citrus County
# 9  2018    FL       Clay County
#
#                                            zip_codes  population  \
# 0  [32601, 32602, 32603, 32604, 32605, 32606, 326...    268851.0
# 1                       [32040, 32063, 32072, 32087]     28353.0
# 2  [32401, 32402, 32403, 32404, 32405, 32406, 324...    186240.0
# 3                [32042, 32044, 32058, 32091, 32622]     27752.0
# 4  [32754, 32775, 32780, 32781, 32782, 32783, 327...    595203.0
# ...

# %%
fl_inc_
