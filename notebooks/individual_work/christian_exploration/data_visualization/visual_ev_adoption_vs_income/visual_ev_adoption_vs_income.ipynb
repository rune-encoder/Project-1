# %%
from scipy.stats import linregress
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns
import hvplot.pandas
import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="bb77ebc9-396b-4877-9748-b49790f65405" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"d29e9d15-6f80-4a44-8f7d-1e7f85609d22":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"9274be7ce4334c24bdae6af1ec360724","client_comm_id":"30336cc5530c40409d53af33767e8a72"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"d29e9d15-6f80-4a44-8f7d-1e7f85609d22","roots":{"p1002":"bb77ebc9-396b-4877-9748-b49790f65405"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Load the data for Counties adoption rate analysis
df = pd.read_csv(
    Path("../../../../../data/processed_data/ev_main_dataset.csv"),
)

# Display the data
print("Shape:", df.shape)
df
# Out:
# Shape: (2011, 10)
#       year state               county  \
# 0     2010    CA       Alameda County
# 1     2010    CA        Amador County
# 2     2010    CA  Contra Costa County
# 3     2010    CA        Fresno County
# 4     2010    CA      Humboldt County
# ...    ...   ...                  ...
# 2006  2022    TX          Wood County
# 2007  2022    TX        Yoakum County
# 2008  2022    TX         Young County
# 2009  2022    TX        Zapata County
# 2010  2022    TX        Zavala County
#
#                                               zip_codes  population  \
# 0     [94501, 94502, 94536, 94537, 94538, 94539, 945...     1512986
# 1     [95601, 95629, 95640, 95642, 95654, 95665, 956...       37886
# 2     [94505, 94506, 94507, 94509, 94511, 94513, 945...     1052540
# 3     [93210, 93234, 93242, 93602, 93605, 93606, 936...      932039
# 4     [95501, 95502, 95503, 95511, 95514, 95518, 955...      135009
# ...                                                 ...         ...
# 2006  [75410, 75444, 75494, 75497, 75765, 75773, 75783]       46930
# 2007                                     [79323, 79355]        7484
# 2008                [76372, 76374, 76450, 76460, 76481]       18012
# 2009                              [78067, 78076, 78564]       13838
# 2010                              [78829, 78839, 78872]        9384
#
#       ev_registrations  cumulative_ev_stations  median_income  \
# 0                   20                       0          69384
# 1                    1                       1          54758
# 2                   10                       0          78385
# 3                    2                       0          46430
# 4                    2                       0          40089
# ...                ...                     ...            ...
# 2006               188                       0          61748
# 2007                10                       1          80317
# 2008                94                       0          65565
# 2009                10                       0          35061
# 2010                12                       0          49243
#
#       ev_adoption_rate  ev_growth_rate
# 0             0.000013             NaN
# 1             0.000026             NaN
# 2             0.000010             NaN
# 3             0.000002             NaN
# 4             0.000015             NaN
# ...                ...             ...
# 2006          0.004006        3.101753
# 2007          0.001336        9.105559
# 2008          0.005219        5.688565
# 2009          0.000723        0.671123
# 2010          0.001279        5.056905
#
# [2011 rows x 10 columns]

# %%
# Inspect the columns of the data
for index, value in enumerate(df.columns):
    print(index, value)
# Out:
# 0 year
# 1 state
# 2 county
# 3 zip_codes
# 4 population
# 5 ev_registrations
# 6 cumulative_ev_stations
# 7 median_income
# 8 ev_adoption_rate
# 9 ev_growth_rate

# %%
# Convert `ev_adoption_rate` and `ev_growth_rate` to percentages
df["ev_adoption_rate"] = df["ev_adoption_rate"] * 100
df["ev_growth_rate"] = df["ev_growth_rate"] * 100

# Display the data
print("Shape:", df.shape)
df
# Out:
# Shape: (2011, 10)
#       year state               county  \
# 0     2010    CA       Alameda County
# 1     2010    CA        Amador County
# 2     2010    CA  Contra Costa County
# 3     2010    CA        Fresno County
# 4     2010    CA      Humboldt County
# ...    ...   ...                  ...
# 2006  2022    TX          Wood County
# 2007  2022    TX        Yoakum County
# 2008  2022    TX         Young County
# 2009  2022    TX        Zapata County
# 2010  2022    TX        Zavala County
#
#                                               zip_codes  population  \
# 0     [94501, 94502, 94536, 94537, 94538, 94539, 945...     1512986
# 1     [95601, 95629, 95640, 95642, 95654, 95665, 956...       37886
# 2     [94505, 94506, 94507, 94509, 94511, 94513, 945...     1052540
# 3     [93210, 93234, 93242, 93602, 93605, 93606, 936...      932039
# 4     [95501, 95502, 95503, 95511, 95514, 95518, 955...      135009
# ...                                                 ...         ...
# 2006  [75410, 75444, 75494, 75497, 75765, 75773, 75783]       46930
# 2007                                     [79323, 79355]        7484
# 2008                [76372, 76374, 76450, 76460, 76481]       18012
# 2009                              [78067, 78076, 78564]       13838
# 2010                              [78829, 78839, 78872]        9384
#
#       ev_registrations  cumulative_ev_stations  median_income  \
# 0                   20                       0          69384
# 1                    1                       1          54758
# 2                   10                       0          78385
# 3                    2                       0          46430
# 4                    2                       0          40089
# ...                ...                     ...            ...
# 2006               188                       0          61748
# 2007                10                       1          80317
# 2008                94                       0          65565
# 2009                10                       0          35061
# 2010                12                       0          49243
#
#       ev_adoption_rate  ev_growth_rate
# 0             0.001322             NaN
# 1             0.002639             NaN
# 2             0.000950             NaN
# 3             0.000215             NaN
# 4             0.001481             NaN
# ...                ...             ...
# 2006          0.400597      310.175344
# 2007          0.133618      910.555852
# 2008          0.521874      568.856477
# 2009          0.072265       67.112299
# 2010          0.127877      505.690537
#
# [2011 rows x 10 columns]

# %%
# Create separate DataFrames for Texas, Florida, and California
tx_df = df[df["state"] == "TX"].sort_values(["year", "state", "county"]).reset_index(drop=True)
fl_df = df[df["state"] == "FL"].sort_values(["year", "state", "county"]).reset_index(drop=True)
ca_df = df[df["state"] == "CA"].sort_values(["year", "state", "county"]).reset_index(drop=True)

# Display the DataFrames
display(tx_df.head(2))
display(fl_df.head(2))
display(ca_df.head(2))
# Out:
#    year state           county  \
# 0  2017    TX  Anderson County
# 1  2017    TX   Andrews County
#
#                                            zip_codes  population  \
# 0  [75763, 75779, 75801, 75802, 75803, 75832, 758...       58175
# 1                                            [79714]       17603
#
#    ev_registrations  cumulative_ev_stations  median_income  ev_adoption_rate  \
# 0                 1                       0          42313          0.001719
# 1                 1                       0          70753          0.005681
#
#    ev_growth_rate
# 0             NaN
# 1             NaN
#    year state          county  \
# 0  2018    FL  Alachua County
# 1  2018    FL    Baker County
#
#                                            zip_codes  population  \
# 0  [32601, 32602, 32603, 32604, 32605, 32606, 326...      268851
# 1                       [32040, 32063, 32072, 32087]       28353
#
#    ev_registrations  cumulative_ev_stations  median_income  ev_adoption_rate  \
# 0               766                      12          49078          0.284916
# 1                 5                       0          61769          0.017635
#
#    ev_growth_rate
# 0             NaN
# 1             NaN
#    year state          county  \
# 0  2010    CA  Alameda County
# 1  2010    CA   Amador County
#
#                                            zip_codes  population  \
# 0  [94501, 94502, 94536, 94537, 94538, 94539, 945...     1512986
# 1  [95601, 95629, 95640, 95642, 95654, 95665, 956...       37886
#
#    ev_registrations  cumulative_ev_stations  median_income  ev_adoption_rate  \
# 0                20                       0          69384          0.001322
# 1                 1                       1          54758          0.002639
#
#    ev_growth_rate
# 0             NaN
# 1             NaN

# %% [markdown]
# # Correlation Matrix

# %%
# Columns to check for correlation
columns_corr = ['ev_adoption_rate', "cumulative_ev_stations", "median_income"]

# %%
# Display the correlation dataframe for all years together for all counties in...
# California, Florida, and Texas

for state_df in [ca_df, fl_df, tx_df]:
    print(f"\033[1m\033[93m{state_df['state'][0]}\033[0m")
    display(state_df[columns_corr].corr().style.background_gradient(cmap='coolwarm'))
# Out:
# CA
# <style type="text/css">
# #T_506c8_row0_col0, #T_506c8_row1_col1, #T_506c8_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_506c8_row0_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_506c8_row0_col2 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_506c8_row1_col0, #T_506c8_row1_col2, #T_506c8_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_506c8_row2_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# </style>
# <table id="T_506c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_506c8_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_506c8_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_506c8_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_506c8_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_506c8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_506c8_row0_col1" class="data row0 col1" >0.463563</td>
#       <td id="T_506c8_row0_col2" class="data row0 col2" >0.749299</td>
#     </tr>
#     <tr>
#       <th id="T_506c8_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_506c8_row1_col0" class="data row1 col0" >0.463563</td>
#       <td id="T_506c8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_506c8_row1_col2" class="data row1 col2" >0.304546</td>
#     </tr>
#     <tr>
#       <th id="T_506c8_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_506c8_row2_col0" class="data row2 col0" >0.749299</td>
#       <td id="T_506c8_row2_col1" class="data row2 col1" >0.304546</td>
#       <td id="T_506c8_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# FL
# <style type="text/css">
# #T_e3d01_row0_col0, #T_e3d01_row1_col1, #T_e3d01_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e3d01_row0_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_e3d01_row0_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_e3d01_row1_col0, #T_e3d01_row1_col2, #T_e3d01_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e3d01_row2_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# </style>
# <table id="T_e3d01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3d01_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_e3d01_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_e3d01_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3d01_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_e3d01_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e3d01_row0_col1" class="data row0 col1" >0.504081</td>
#       <td id="T_e3d01_row0_col2" class="data row0 col2" >0.683570</td>
#     </tr>
#     <tr>
#       <th id="T_e3d01_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_e3d01_row1_col0" class="data row1 col0" >0.504081</td>
#       <td id="T_e3d01_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e3d01_row1_col2" class="data row1 col2" >0.281179</td>
#     </tr>
#     <tr>
#       <th id="T_e3d01_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_e3d01_row2_col0" class="data row2 col0" >0.683570</td>
#       <td id="T_e3d01_row2_col1" class="data row2 col1" >0.281179</td>
#       <td id="T_e3d01_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# TX
# <style type="text/css">
# #T_959a5_row0_col0, #T_959a5_row1_col1, #T_959a5_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_959a5_row0_col1 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_959a5_row0_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_959a5_row1_col0, #T_959a5_row1_col2, #T_959a5_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_959a5_row2_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_959a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_959a5_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_959a5_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_959a5_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_959a5_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_959a5_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_959a5_row0_col1" class="data row0 col1" >0.443204</td>
#       <td id="T_959a5_row0_col2" class="data row0 col2" >0.447105</td>
#     </tr>
#     <tr>
#       <th id="T_959a5_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_959a5_row1_col0" class="data row1 col0" >0.443204</td>
#       <td id="T_959a5_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_959a5_row1_col2" class="data row1 col2" >0.237789</td>
#     </tr>
#     <tr>
#       <th id="T_959a5_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_959a5_row2_col0" class="data row2 col0" >0.447105</td>
#       <td id="T_959a5_row2_col1" class="data row2 col1" >0.237789</td>
#       <td id="T_959a5_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Display correlation dataframe for every year in the California DataFrame
print("\033[1m\033[96mCalifornia\033[0m")
for year in ca_df["year"].unique():
    ca_year_df = ca_df[ca_df["year"] == year]
    print(f"\033[1m\033[93m{year}\033[0m")
    display(ca_year_df[columns_corr].corr().style.background_gradient(cmap='coolwarm'))
# Out:
# California
# 2010
# <style type="text/css">
# #T_632b8_row0_col0, #T_632b8_row1_col1, #T_632b8_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_632b8_row0_col1 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_632b8_row0_col2 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_632b8_row1_col0, #T_632b8_row1_col2, #T_632b8_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_632b8_row2_col0 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# </style>
# <table id="T_632b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_632b8_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_632b8_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_632b8_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_632b8_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_632b8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_632b8_row0_col1" class="data row0 col1" >0.190233</td>
#       <td id="T_632b8_row0_col2" class="data row0 col2" >0.686716</td>
#     </tr>
#     <tr>
#       <th id="T_632b8_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_632b8_row1_col0" class="data row1 col0" >0.190233</td>
#       <td id="T_632b8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_632b8_row1_col2" class="data row1 col2" >-0.102791</td>
#     </tr>
#     <tr>
#       <th id="T_632b8_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_632b8_row2_col0" class="data row2 col0" >0.686716</td>
#       <td id="T_632b8_row2_col1" class="data row2 col1" >-0.102791</td>
#       <td id="T_632b8_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2011
# <style type="text/css">
# #T_5f30b_row0_col0, #T_5f30b_row1_col1, #T_5f30b_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5f30b_row0_col1, #T_5f30b_row1_col0, #T_5f30b_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5f30b_row0_col2 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_5f30b_row2_col0 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_5f30b_row2_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5f30b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f30b_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_5f30b_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_5f30b_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f30b_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_5f30b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5f30b_row0_col1" class="data row0 col1" >0.135584</td>
#       <td id="T_5f30b_row0_col2" class="data row0 col2" >0.808851</td>
#     </tr>
#     <tr>
#       <th id="T_5f30b_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_5f30b_row1_col0" class="data row1 col0" >0.135584</td>
#       <td id="T_5f30b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5f30b_row1_col2" class="data row1 col2" >0.210520</td>
#     </tr>
#     <tr>
#       <th id="T_5f30b_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_5f30b_row2_col0" class="data row2 col0" >0.808851</td>
#       <td id="T_5f30b_row2_col1" class="data row2 col1" >0.210520</td>
#       <td id="T_5f30b_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2012
# <style type="text/css">
# #T_632be_row0_col0, #T_632be_row1_col1, #T_632be_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_632be_row0_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_632be_row0_col2 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_632be_row1_col0, #T_632be_row1_col2, #T_632be_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_632be_row2_col0 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_632be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_632be_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_632be_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_632be_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_632be_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_632be_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_632be_row0_col1" class="data row0 col1" >0.361303</td>
#       <td id="T_632be_row0_col2" class="data row0 col2" >0.871264</td>
#     </tr>
#     <tr>
#       <th id="T_632be_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_632be_row1_col0" class="data row1 col0" >0.361303</td>
#       <td id="T_632be_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_632be_row1_col2" class="data row1 col2" >0.328843</td>
#     </tr>
#     <tr>
#       <th id="T_632be_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_632be_row2_col0" class="data row2 col0" >0.871264</td>
#       <td id="T_632be_row2_col1" class="data row2 col1" >0.328843</td>
#       <td id="T_632be_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2013
# <style type="text/css">
# #T_cdf6d_row0_col0, #T_cdf6d_row1_col1, #T_cdf6d_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cdf6d_row0_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_cdf6d_row0_col2 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_cdf6d_row1_col0, #T_cdf6d_row1_col2, #T_cdf6d_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_cdf6d_row2_col0 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cdf6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdf6d_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_cdf6d_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_cdf6d_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdf6d_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_cdf6d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_cdf6d_row0_col1" class="data row0 col1" >0.319455</td>
#       <td id="T_cdf6d_row0_col2" class="data row0 col2" >0.861584</td>
#     </tr>
#     <tr>
#       <th id="T_cdf6d_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_cdf6d_row1_col0" class="data row1 col0" >0.319455</td>
#       <td id="T_cdf6d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_cdf6d_row1_col2" class="data row1 col2" >0.298666</td>
#     </tr>
#     <tr>
#       <th id="T_cdf6d_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_cdf6d_row2_col0" class="data row2 col0" >0.861584</td>
#       <td id="T_cdf6d_row2_col1" class="data row2 col1" >0.298666</td>
#       <td id="T_cdf6d_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2014
# <style type="text/css">
# #T_5be0c_row0_col0, #T_5be0c_row1_col1, #T_5be0c_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5be0c_row0_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_5be0c_row0_col2 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_5be0c_row1_col0, #T_5be0c_row1_col2, #T_5be0c_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5be0c_row2_col0 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5be0c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5be0c_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_5be0c_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_5be0c_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5be0c_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_5be0c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5be0c_row0_col1" class="data row0 col1" >0.326211</td>
#       <td id="T_5be0c_row0_col2" class="data row0 col2" >0.858518</td>
#     </tr>
#     <tr>
#       <th id="T_5be0c_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_5be0c_row1_col0" class="data row1 col0" >0.326211</td>
#       <td id="T_5be0c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5be0c_row1_col2" class="data row1 col2" >0.295130</td>
#     </tr>
#     <tr>
#       <th id="T_5be0c_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_5be0c_row2_col0" class="data row2 col0" >0.858518</td>
#       <td id="T_5be0c_row2_col1" class="data row2 col1" >0.295130</td>
#       <td id="T_5be0c_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2015
# <style type="text/css">
# #T_84a19_row0_col0, #T_84a19_row1_col1, #T_84a19_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_84a19_row0_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_84a19_row0_col2 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_84a19_row1_col0, #T_84a19_row1_col2, #T_84a19_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_84a19_row2_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_84a19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84a19_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_84a19_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_84a19_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84a19_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_84a19_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_84a19_row0_col1" class="data row0 col1" >0.363330</td>
#       <td id="T_84a19_row0_col2" class="data row0 col2" >0.861197</td>
#     </tr>
#     <tr>
#       <th id="T_84a19_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_84a19_row1_col0" class="data row1 col0" >0.363330</td>
#       <td id="T_84a19_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_84a19_row1_col2" class="data row1 col2" >0.317925</td>
#     </tr>
#     <tr>
#       <th id="T_84a19_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_84a19_row2_col0" class="data row2 col0" >0.861197</td>
#       <td id="T_84a19_row2_col1" class="data row2 col1" >0.317925</td>
#       <td id="T_84a19_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2016
# <style type="text/css">
# #T_a2e7e_row0_col0, #T_a2e7e_row1_col1, #T_a2e7e_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a2e7e_row0_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_a2e7e_row0_col2 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_a2e7e_row1_col0, #T_a2e7e_row1_col2, #T_a2e7e_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a2e7e_row2_col0 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a2e7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2e7e_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_a2e7e_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_a2e7e_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2e7e_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_a2e7e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a2e7e_row0_col1" class="data row0 col1" >0.377670</td>
#       <td id="T_a2e7e_row0_col2" class="data row0 col2" >0.862134</td>
#     </tr>
#     <tr>
#       <th id="T_a2e7e_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_a2e7e_row1_col0" class="data row1 col0" >0.377670</td>
#       <td id="T_a2e7e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a2e7e_row1_col2" class="data row1 col2" >0.314894</td>
#     </tr>
#     <tr>
#       <th id="T_a2e7e_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_a2e7e_row2_col0" class="data row2 col0" >0.862134</td>
#       <td id="T_a2e7e_row2_col1" class="data row2 col1" >0.314894</td>
#       <td id="T_a2e7e_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2017
# <style type="text/css">
# #T_4e75c_row0_col0, #T_4e75c_row1_col1, #T_4e75c_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4e75c_row0_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_4e75c_row0_col2 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_4e75c_row1_col0, #T_4e75c_row1_col2, #T_4e75c_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4e75c_row2_col0 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4e75c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e75c_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_4e75c_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_4e75c_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e75c_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_4e75c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4e75c_row0_col1" class="data row0 col1" >0.416052</td>
#       <td id="T_4e75c_row0_col2" class="data row0 col2" >0.864621</td>
#     </tr>
#     <tr>
#       <th id="T_4e75c_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_4e75c_row1_col0" class="data row1 col0" >0.416052</td>
#       <td id="T_4e75c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4e75c_row1_col2" class="data row1 col2" >0.333868</td>
#     </tr>
#     <tr>
#       <th id="T_4e75c_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_4e75c_row2_col0" class="data row2 col0" >0.864621</td>
#       <td id="T_4e75c_row2_col1" class="data row2 col1" >0.333868</td>
#       <td id="T_4e75c_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2018
# <style type="text/css">
# #T_9997e_row0_col0, #T_9997e_row1_col1, #T_9997e_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9997e_row0_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_9997e_row0_col2 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_9997e_row1_col0, #T_9997e_row1_col2, #T_9997e_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9997e_row2_col0 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9997e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9997e_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_9997e_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_9997e_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9997e_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_9997e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9997e_row0_col1" class="data row0 col1" >0.407480</td>
#       <td id="T_9997e_row0_col2" class="data row0 col2" >0.893217</td>
#     </tr>
#     <tr>
#       <th id="T_9997e_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_9997e_row1_col0" class="data row1 col0" >0.407480</td>
#       <td id="T_9997e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9997e_row1_col2" class="data row1 col2" >0.324354</td>
#     </tr>
#     <tr>
#       <th id="T_9997e_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_9997e_row2_col0" class="data row2 col0" >0.893217</td>
#       <td id="T_9997e_row2_col1" class="data row2 col1" >0.324354</td>
#       <td id="T_9997e_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2019
# <style type="text/css">
# #T_47d59_row0_col0, #T_47d59_row1_col1, #T_47d59_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_47d59_row0_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_47d59_row0_col2 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_47d59_row1_col0, #T_47d59_row1_col2, #T_47d59_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_47d59_row2_col0 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_47d59">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47d59_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_47d59_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_47d59_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47d59_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_47d59_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_47d59_row0_col1" class="data row0 col1" >0.398726</td>
#       <td id="T_47d59_row0_col2" class="data row0 col2" >0.905708</td>
#     </tr>
#     <tr>
#       <th id="T_47d59_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_47d59_row1_col0" class="data row1 col0" >0.398726</td>
#       <td id="T_47d59_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_47d59_row1_col2" class="data row1 col2" >0.311329</td>
#     </tr>
#     <tr>
#       <th id="T_47d59_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_47d59_row2_col0" class="data row2 col0" >0.905708</td>
#       <td id="T_47d59_row2_col1" class="data row2 col1" >0.311329</td>
#       <td id="T_47d59_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2020
# <style type="text/css">
# #T_6ecb3_row0_col0, #T_6ecb3_row1_col1, #T_6ecb3_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6ecb3_row0_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_6ecb3_row0_col2 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_6ecb3_row1_col0, #T_6ecb3_row1_col2, #T_6ecb3_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6ecb3_row2_col0 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6ecb3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ecb3_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_6ecb3_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_6ecb3_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ecb3_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_6ecb3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6ecb3_row0_col1" class="data row0 col1" >0.432236</td>
#       <td id="T_6ecb3_row0_col2" class="data row0 col2" >0.892751</td>
#     </tr>
#     <tr>
#       <th id="T_6ecb3_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_6ecb3_row1_col0" class="data row1 col0" >0.432236</td>
#       <td id="T_6ecb3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6ecb3_row1_col2" class="data row1 col2" >0.325308</td>
#     </tr>
#     <tr>
#       <th id="T_6ecb3_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_6ecb3_row2_col0" class="data row2 col0" >0.892751</td>
#       <td id="T_6ecb3_row2_col1" class="data row2 col1" >0.325308</td>
#       <td id="T_6ecb3_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Display correlation dataframe for every year in the Florida DataFrame
print("\033[1m\033[96mFlorida\033[0m")
for year in fl_df["year"].unique():
    fl_year_df = fl_df[fl_df["year"] == year]
    print(f"\033[1m\033[93m{year}\033[0m")
    display(fl_year_df[columns_corr].corr().style.background_gradient(cmap='coolwarm'))
# Out:
# Florida
# 2018
# <style type="text/css">
# #T_dc04a_row0_col0, #T_dc04a_row1_col1, #T_dc04a_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_dc04a_row0_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_dc04a_row0_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_dc04a_row1_col0, #T_dc04a_row1_col2, #T_dc04a_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_dc04a_row2_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# </style>
# <table id="T_dc04a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc04a_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_dc04a_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_dc04a_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc04a_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_dc04a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_dc04a_row0_col1" class="data row0 col1" >0.589621</td>
#       <td id="T_dc04a_row0_col2" class="data row0 col2" >0.738281</td>
#     </tr>
#     <tr>
#       <th id="T_dc04a_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_dc04a_row1_col0" class="data row1 col0" >0.589621</td>
#       <td id="T_dc04a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_dc04a_row1_col2" class="data row1 col2" >0.292303</td>
#     </tr>
#     <tr>
#       <th id="T_dc04a_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_dc04a_row2_col0" class="data row2 col0" >0.738281</td>
#       <td id="T_dc04a_row2_col1" class="data row2 col1" >0.292303</td>
#       <td id="T_dc04a_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2019
# <style type="text/css">
# #T_8d806_row0_col0, #T_8d806_row1_col1, #T_8d806_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8d806_row0_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_8d806_row0_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_8d806_row1_col0, #T_8d806_row1_col2, #T_8d806_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8d806_row2_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# </style>
# <table id="T_8d806">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d806_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_8d806_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_8d806_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d806_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_8d806_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8d806_row0_col1" class="data row0 col1" >0.572156</td>
#       <td id="T_8d806_row0_col2" class="data row0 col2" >0.760462</td>
#     </tr>
#     <tr>
#       <th id="T_8d806_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_8d806_row1_col0" class="data row1 col0" >0.572156</td>
#       <td id="T_8d806_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8d806_row1_col2" class="data row1 col2" >0.289728</td>
#     </tr>
#     <tr>
#       <th id="T_8d806_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_8d806_row2_col0" class="data row2 col0" >0.760462</td>
#       <td id="T_8d806_row2_col1" class="data row2 col1" >0.289728</td>
#       <td id="T_8d806_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2020
# <style type="text/css">
# #T_3cd9e_row0_col0, #T_3cd9e_row1_col1, #T_3cd9e_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3cd9e_row0_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_3cd9e_row0_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_3cd9e_row1_col0, #T_3cd9e_row1_col2, #T_3cd9e_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3cd9e_row2_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# </style>
# <table id="T_3cd9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cd9e_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_3cd9e_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_3cd9e_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cd9e_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_3cd9e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_3cd9e_row0_col1" class="data row0 col1" >0.563740</td>
#       <td id="T_3cd9e_row0_col2" class="data row0 col2" >0.756060</td>
#     </tr>
#     <tr>
#       <th id="T_3cd9e_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_3cd9e_row1_col0" class="data row1 col0" >0.563740</td>
#       <td id="T_3cd9e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_3cd9e_row1_col2" class="data row1 col2" >0.276540</td>
#     </tr>
#     <tr>
#       <th id="T_3cd9e_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_3cd9e_row2_col0" class="data row2 col0" >0.756060</td>
#       <td id="T_3cd9e_row2_col1" class="data row2 col1" >0.276540</td>
#       <td id="T_3cd9e_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2021
# <style type="text/css">
# #T_df243_row0_col0, #T_df243_row1_col1, #T_df243_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_df243_row0_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_df243_row0_col2 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_df243_row1_col0, #T_df243_row1_col2, #T_df243_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_df243_row2_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# </style>
# <table id="T_df243">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df243_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_df243_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_df243_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df243_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_df243_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_df243_row0_col1" class="data row0 col1" >0.566145</td>
#       <td id="T_df243_row0_col2" class="data row0 col2" >0.757842</td>
#     </tr>
#     <tr>
#       <th id="T_df243_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_df243_row1_col0" class="data row1 col0" >0.566145</td>
#       <td id="T_df243_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_df243_row1_col2" class="data row1 col2" >0.242876</td>
#     </tr>
#     <tr>
#       <th id="T_df243_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_df243_row2_col0" class="data row2 col0" >0.757842</td>
#       <td id="T_df243_row2_col1" class="data row2 col1" >0.242876</td>
#       <td id="T_df243_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Display correlation dataframe for every year in the Texas DataFrame
print("\033[1m\033[96mTexas\033[0m")

for year in tx_df["year"].unique():
    tx_year_df = tx_df[tx_df["year"] == year]
    print(f"\033[1m\033[93m{year}\033[0m")
    display(tx_year_df[columns_corr].corr().style.background_gradient(cmap='coolwarm'))
# Out:
# Texas
# 2017
# <style type="text/css">
# #T_6042a_row0_col0, #T_6042a_row1_col1, #T_6042a_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6042a_row0_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_6042a_row0_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_6042a_row1_col0, #T_6042a_row1_col2, #T_6042a_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6042a_row2_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6042a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6042a_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_6042a_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_6042a_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6042a_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_6042a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6042a_row0_col1" class="data row0 col1" >0.339293</td>
#       <td id="T_6042a_row0_col2" class="data row0 col2" >0.409622</td>
#     </tr>
#     <tr>
#       <th id="T_6042a_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_6042a_row1_col0" class="data row1 col0" >0.339293</td>
#       <td id="T_6042a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6042a_row1_col2" class="data row1 col2" >0.225475</td>
#     </tr>
#     <tr>
#       <th id="T_6042a_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_6042a_row2_col0" class="data row2 col0" >0.409622</td>
#       <td id="T_6042a_row2_col1" class="data row2 col1" >0.225475</td>
#       <td id="T_6042a_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2018
# <style type="text/css">
# #T_44ecd_row0_col0, #T_44ecd_row1_col1, #T_44ecd_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_44ecd_row0_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_44ecd_row0_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_44ecd_row1_col0, #T_44ecd_row1_col2, #T_44ecd_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_44ecd_row2_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_44ecd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44ecd_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_44ecd_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_44ecd_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44ecd_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_44ecd_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_44ecd_row0_col1" class="data row0 col1" >0.364791</td>
#       <td id="T_44ecd_row0_col2" class="data row0 col2" >0.385041</td>
#     </tr>
#     <tr>
#       <th id="T_44ecd_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_44ecd_row1_col0" class="data row1 col0" >0.364791</td>
#       <td id="T_44ecd_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_44ecd_row1_col2" class="data row1 col2" >0.256580</td>
#     </tr>
#     <tr>
#       <th id="T_44ecd_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_44ecd_row2_col0" class="data row2 col0" >0.385041</td>
#       <td id="T_44ecd_row2_col1" class="data row2 col1" >0.256580</td>
#       <td id="T_44ecd_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2019
# <style type="text/css">
# #T_542e2_row0_col0, #T_542e2_row1_col1, #T_542e2_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_542e2_row0_col1 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_542e2_row0_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_542e2_row1_col0, #T_542e2_row1_col2, #T_542e2_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_542e2_row2_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_542e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_542e2_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_542e2_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_542e2_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_542e2_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_542e2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_542e2_row0_col1" class="data row0 col1" >0.522915</td>
#       <td id="T_542e2_row0_col2" class="data row0 col2" >0.562532</td>
#     </tr>
#     <tr>
#       <th id="T_542e2_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_542e2_row1_col0" class="data row1 col0" >0.522915</td>
#       <td id="T_542e2_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_542e2_row1_col2" class="data row1 col2" >0.261650</td>
#     </tr>
#     <tr>
#       <th id="T_542e2_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_542e2_row2_col0" class="data row2 col0" >0.562532</td>
#       <td id="T_542e2_row2_col1" class="data row2 col1" >0.261650</td>
#       <td id="T_542e2_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2020
# <style type="text/css">
# #T_42dc7_row0_col0, #T_42dc7_row1_col1, #T_42dc7_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_42dc7_row0_col1 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_42dc7_row0_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_42dc7_row1_col0, #T_42dc7_row1_col2, #T_42dc7_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_42dc7_row2_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_42dc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42dc7_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_42dc7_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_42dc7_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42dc7_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_42dc7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_42dc7_row0_col1" class="data row0 col1" >0.555732</td>
#       <td id="T_42dc7_row0_col2" class="data row0 col2" >0.583729</td>
#     </tr>
#     <tr>
#       <th id="T_42dc7_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_42dc7_row1_col0" class="data row1 col0" >0.555732</td>
#       <td id="T_42dc7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_42dc7_row1_col2" class="data row1 col2" >0.241269</td>
#     </tr>
#     <tr>
#       <th id="T_42dc7_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_42dc7_row2_col0" class="data row2 col0" >0.583729</td>
#       <td id="T_42dc7_row2_col1" class="data row2 col1" >0.241269</td>
#       <td id="T_42dc7_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2021
# <style type="text/css">
# #T_165e4_row0_col0, #T_165e4_row1_col1, #T_165e4_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_165e4_row0_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_165e4_row0_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_165e4_row1_col0, #T_165e4_row1_col2, #T_165e4_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_165e4_row2_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_165e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_165e4_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_165e4_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_165e4_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_165e4_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_165e4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_165e4_row0_col1" class="data row0 col1" >0.589529</td>
#       <td id="T_165e4_row0_col2" class="data row0 col2" >0.629420</td>
#     </tr>
#     <tr>
#       <th id="T_165e4_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_165e4_row1_col0" class="data row1 col0" >0.589529</td>
#       <td id="T_165e4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_165e4_row1_col2" class="data row1 col2" >0.232953</td>
#     </tr>
#     <tr>
#       <th id="T_165e4_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_165e4_row2_col0" class="data row2 col0" >0.629420</td>
#       <td id="T_165e4_row2_col1" class="data row2 col1" >0.232953</td>
#       <td id="T_165e4_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2022
# <style type="text/css">
# #T_9a28c_row0_col0, #T_9a28c_row1_col1, #T_9a28c_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9a28c_row0_col1 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_9a28c_row0_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_9a28c_row1_col0, #T_9a28c_row1_col2, #T_9a28c_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9a28c_row2_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9a28c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a28c_level0_col0" class="col_heading level0 col0" >ev_adoption_rate</th>
#       <th id="T_9a28c_level0_col1" class="col_heading level0 col1" >cumulative_ev_stations</th>
#       <th id="T_9a28c_level0_col2" class="col_heading level0 col2" >median_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a28c_level0_row0" class="row_heading level0 row0" >ev_adoption_rate</th>
#       <td id="T_9a28c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9a28c_row0_col1" class="data row0 col1" >0.531191</td>
#       <td id="T_9a28c_row0_col2" class="data row0 col2" >0.557665</td>
#     </tr>
#     <tr>
#       <th id="T_9a28c_level0_row1" class="row_heading level0 row1" >cumulative_ev_stations</th>
#       <td id="T_9a28c_row1_col0" class="data row1 col0" >0.531191</td>
#       <td id="T_9a28c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9a28c_row1_col2" class="data row1 col2" >0.256879</td>
#     </tr>
#     <tr>
#       <th id="T_9a28c_level0_row2" class="row_heading level0 row2" >median_income</th>
#       <td id="T_9a28c_row2_col0" class="data row2 col0" >0.557665</td>
#       <td id="T_9a28c_row2_col1" class="data row2 col1" >0.256879</td>
#       <td id="T_9a28c_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Correlation Visualization: Scatter Plots

# %%
# Create a dictionary of styles to use with axes for titles, labels, and legends

# Set the style for the plot title
title_style = {
    "color": "#2c3e50",  
    "fontsize": 22,       
    "fontweight": "bold",
    "fontfamily": "DejaVu Sans", 
    "ha": "center", 
}

# Set the style for the x and y labels
axis_style = {
    "color": "#34495e",
    "fontsize": 18,
    "fontweight": "semibold",
    "fontfamily": "DejaVu Sans",
    "fontstyle": "italic",
}

# Set the style for legend
legend_style = {
    "fontsize": "small",
    "frameon": True,
    "facecolor": "#ecf0f1",
    "edgecolor": "#bdc3c7",
    "labelspacing": 1,
    "shadow": True,
}

# %%
# Create a function to create a custom scatter plot
def create_scatter_plot(df, x, y, hue, title, xlabel, ylabel):
    # Set the style to darkgrid
    sns.set_theme(style="darkgrid", palette="deep")
    
    fig, ax = plt.subplots(figsize=(10, 5))
    
    # Create scatter plot
    ax = sns.scatterplot(data=df, x=x, y=y, hue=hue)
    
    # Customize title and labels using styles
    ax.set_title(title, fontdict=title_style)
    ax.set_xlabel(xlabel, fontdict=axis_style)
    ax.set_ylabel(ylabel, fontdict=axis_style)
    
    # Remove legend
    ax.legend().remove()
    
    # Plot linear regression line
    slope, intercept, r_value, p_value, std_err = linregress(df[x], df[y])
    ax.plot(df[x], (slope * df[x]) + intercept, color='salmon', alpha=0.9)

    fig.tight_layout()

    return fig, ax

# %% [markdown]
# # Texas Correlation Analysis:

# %%
fig, ax = create_scatter_plot(
    df=tx_df, 
    x='ev_adoption_rate', 
    y='cumulative_ev_stations', 
    hue='county', 
    title='Texas: EV Adoption Rate vs. Cumulative EV Stations', 
    xlabel='EV Adoption Rate (%)',
    ylabel='Cumulative EV Stations'
)

file_name = "tx_ev_adoption_rate_vs_cumulative_ev_stations.png"
file_path = Path(f"../../../../../reports/figures/correlation_counties/{file_name}")

fig.savefig(file_path, bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 14
#      11 file_name = "tx_ev_adoption_rate_vs_cumulative_ev_stations.png"
#      12 file_path = Path(f"../../../../../reports/figures/correlation_counties/{file_name}")
# ---> 14 fig.savefig(file_path, bbox_inches="tight")
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\backends\backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\backends\backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\matplotlib\image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File c:\Users\chris\anaconda3\envs\dev\lib\site-packages\PIL\Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\chris\\Code\\AI-UTSA-2024\\Projects\\Project-1\\reports\\figures\\correlation_counties\\tx_ev_adoption_rate_vs_cumulative_ev_stations.png'

# %%
fig, ax = create_scatter_plot(
    df=tx_df, 
    y='ev_adoption_rate', 
    x='median_income', 
    hue='county', 
    title='Texas: EV Adoption Rate vs. Median Income', 
    ylabel='EV Adoption Rate (%)',
    xlabel='Median Income'
)

file_name = "tx_ev_adoption_rate_vs_median_income.png"
file_path = Path(f"../../../../../reports/figures/correlation_counties/{file_name}")

fig.savefig(file_path, bbox_inches="tight")

# %% [markdown]
# # Florida Correlation Analysis:

# %%
fig, ax = create_scatter_plot(
    df=fl_df, 
    x='ev_adoption_rate', 
    y='cumulative_ev_stations', 
    hue='county', 
    title='Florida: EV Adoption Rate vs. Cumulative EV Stations', 
    xlabel='EV Adoption Rate (%)',
    ylabel='Cumulative EV Stations'
)

file_name = "fl_ev_adoption_rate_vs_cumulative_ev_stations.png"
file_path = Path(f"../../../../../reports/figures/correlation_counties/{file_name}")

fig.savefig(file_path, bbox_inches="tight")

# %%
fig, ax = create_scatter_plot(
    df=fl_df, 
    y='ev_adoption_rate', 
    x='median_income', 
    hue='county', 
    title='Florida: EV Adoption Rate vs. Median Income', 
    ylabel='EV Adoption Rate (%)',
    xlabel='Median Income'
)

file_name = "fl_ev_adoption_rate_vs_median_income.png"
file_path = Path(f"../../../../../reports/figures/correlation_counties/{file_name}")

fig.savefig(file_path, bbox_inches="tight")

# %% [markdown]
# # California Correlation Analysis:

# %%
fig, ax = create_scatter_plot(
    df=ca_df, 
    x='ev_adoption_rate', 
    y='cumulative_ev_stations', 
    hue='county', 
    title='California: EV Adoption Rate vs. Cumulative EV Stations', 
    xlabel='EV Adoption Rate (%)',
    ylabel='Cumulative EV Stations'
)

file_name = "ca_ev_adoption_rate_vs_cumulative_ev_stations.png"
file_path = Path(f"../../../../../reports/figures/correlation_counties/{file_name}")

fig.savefig(file_path, bbox_inches="tight")

# %%
fig, ax = create_scatter_plot(
    df=ca_df, 
    y='ev_adoption_rate', 
    x='median_income', 
    hue='county', 
    title='California: EV Adoption Rate vs. Median Income', 
    ylabel='EV Adoption Rate (%)',
    xlabel='Median Income'
)

file_name = "ca_ev_adoption_rate_vs_median_income.png"
file_path = Path(f"../../../../../reports/figures/correlation_counties/{file_name}")

fig.savefig(file_path, bbox_inches="tight")
